# %%
from __future__ import print_function
#%matplotlib inline
import argparse
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# %%
from PIL import Image
import PIL.Image as pilimg
import numpy as np
import matplotlib.pyplot as plt

# %%
import importlib
importlib.reload(GAN_utils)
from GAN_utils import *

# %% [markdown]
# ---

# %% [markdown]
# #### 1. 이미지 로딩
# - 픽셀 확인
# - 어떤 포맷이 좋을지?
# - 픽셀 더하기 빼기 / manipulation
# - 파이토치 데이터로더

# %%
# list of images
ori_list = os.listdir("../dorsal_left")
dot_list = os.listdir("../label1")

# %%
# create new folder 
from datetime import date
today = date.today()
d1 = today.strftime("%d_%m_%Y")
dirs = 'new_'+d1
os.chdir('./'+dirs)

# %%
# reconstruct images 
for i in range (len(dot_list)):
    im_o = plt.imread('../dorsal_left/'+ori_list[i])
    im_d = plt.imread('../label1/'+dot_list[i])
    im_c = construct_dots(im_o, im_d)
    save_arr_to_img (im_c, name = dot_list[i][:-4])
# Out:
# Saving img Hand_0000021 as png format
# Saving img Hand_0000022 as png format
# Saving img Hand_0000023 as png format
# Saving img Hand_0000024 as png format
# Saving img Hand_0000025 as png format
# Saving img Hand_0000026 as png format
# Saving img Hand_0000027 as png format
# Saving img Hand_0000028 as png format
# Saving img Hand_0000029 as png format
# Saving img Hand_0000030 as png format
# Saving img Hand_0000031 as png format
# Saving img Hand_0000032 as png format
# Saving img Hand_0000033 as png format
# Saving img Hand_0000034 as png format
# Saving img Hand_0000070 as png format
# Saving img Hand_0000071 as png format
# Saving img Hand_0000072 as png format
# Saving img Hand_0000073 as png format
# Saving img Hand_0000074 as png format
# Saving img Hand_0000075 as png format
# Saving img Hand_0000076 as png format
# Saving img Hand_0000077 as png format
# Saving img Hand_0000078 as png format
# Saving img Hand_0000079 as png format
# Saving img Hand_0000091 as png format
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# #### 2. 이미지 전처리
# - 전부 동일한 사이즈로 만들기
# - normalization 수행
#     - 이 과정 실행 시 점은 바뀌는지?

# %% [markdown]
# ---

# %% [markdown]
# #### 3. GAN architecture
# - discriminator
# - generator

# %% [markdown]
# ---

# %% [markdown]
# #### 4. Training
# - train and validate function
# - monitoring
#     - show change in data-distribution
#     - is there a way to save the stream of images?
#     - how long does training take?

# %% [markdown]
# ---

# %% [markdown]
# #### 5. Resuluts
# - save results
#     - model
#     - manifested images
