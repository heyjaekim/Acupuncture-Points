# %%
import importlib
import Training_utils
import torchvision
from torchvision import transforms
import tb_utils
#importlib.reload(tb_utils)
from tb_utils import *
importlib.reload(Training_utils)
from Training_utils import *
from Image_Process_utils import *
# Out:
# current path: C:\Users\NormalKim\[0_BigData_Acu]\Acupuncture-Points\CV_DeepLearning

# %%
model = MyResNet(block = BasicBlock, cfg = [3,4,6,3]) # 레즈넷 50
model.load_state_dict(torch.load('ResNet50_0812_e13.pth'))
# Out:
# <All keys matched successfully>

# %%
os.listdir()

# %%
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f50e87ebd4c1> in <module>
#       1 from PIL import Image
# ----> 2 PIL_image = Image.fromarray(ndarray_image)
#
# NameError: name 'ndarray_image' is not defined

# %%
imtest = plt.imread('./Acu_Dataset/1_org.jpg')
#imtest = imtest/255.0

# %%
plt.imshow(imtest)

# %%
plt.imshow(imtest)

# %%
# resize
imtest = Image.fromarray(imtest)
my_transforms = transforms.Compose([
    transforms.Resize(700),
    transforms.ToTensor()
    #transforms.Normalize((0.5,), (0.5,)),
    ])
imtest = my_transforms(imtest)
#imtest = np.array(imtest)

# %%
imtest = imtest.unsqueeze(0)

# %%
model(imtest)
# Out:
# (tensor([[-0.1791]], grad_fn=<AddmmBackward>),
#  tensor([[188.2393, 192.6369]], grad_fn=<AddmmBackward>))

# %%
plt.imshow(create_circle_patch(imtest,181.4518, 185.8013 ))
