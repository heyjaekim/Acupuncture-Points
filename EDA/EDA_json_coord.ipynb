# %% [markdown]
# ### 혈위 별 pointing 된 x,y 좌표값에 대해 EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import json

# %%
with open('./json files/gwanchung_info_수정.json') as json_file:
    gwanchung = json.load(json_file)
    
gwanchung_x, gwanchung_y = list(),list()
for i in gwanchung.keys():
    gwanchung_x.append(gwanchung[i][1]['acup_coord_x'])
    gwanchung_y.append(gwanchung[i][1]['acup_coord_y'])
    
######################################################################    

with open('./json files/hapgok_info_수정.json') as json_file:
    hapgok = json.load(json_file)
    
hapgok_x, hapgok_y = list(),list()
for i in hapgok.keys():
    hapgok_x.append(hapgok[i][1]['acup_coord_x'])
    hapgok_y.append(hapgok[i][1]['acup_coord_y'])
    
######################################################################    

with open('./json files/hugye_info_수정.json') as json_file:
    hugye = json.load(json_file)
    
hugye_x, hugye_y = list(),list()
for i in hugye.keys():
    hugye_x.append(hugye[i][1]['acup_coord_x'])
    hugye_y.append(hugye[i][1]['acup_coord_y'])
    
######################################################################    

with open('./json files/nogung_info_수정.json') as json_file:
    nogung = json.load(json_file)
    
nogung_x, nogung_y = list(),list()
for i in nogung.keys():
    nogung_x.append(nogung[i][1]['acup_coord_x'])
    nogung_y.append(nogung[i][1]['acup_coord_y'])

#####################################################################    

with open('./json files/sangyang_info_수정.json') as json_file:
    sangyang = json.load(json_file)
    
sangyang_x, sangyang_y = list(),list()
for i in sangyang.keys():
    sangyang_x.append(sangyang[i][1]['acup_coord_x'])
    sangyang_y.append(sangyang[i][1]['acup_coord_y'])

######################################################################    

with open('./json files/shinmoon_info_수정.json') as json_file:
    shinmoon = json.load(json_file)
    
shinmoon_x, shinmoon_y = list(),list()
for i in shinmoon.keys():
    shinmoon_x.append(shinmoon[i][1]['acup_coord_x'])
    shinmoon_y.append(shinmoon[i][1]['acup_coord_y'])

######################################################################    

with open('./json files/sobu_info_수정.json') as json_file:
    sobu = json.load(json_file)
    
sobu_x, sobu_y = list(),list()
for i in sobu.keys():
    sobu_x.append(sobu[i][1]['acup_coord_x'])
    sobu_y.append(sobu[i][1]['acup_coord_y'])
######################################################################    

with open('./json files/sochung_info_수정.json') as json_file:
    sochung = json.load(json_file)
    
sochung_x, sochung_y = list(),list()
for i in sochung.keys():
    sochung_x.append(sochung[i][1]['acup_coord_x'])
    sochung_y.append(sochung[i][1]['acup_coord_y'])
######################################################################    

with open('./json files/sotack_info_수정.json') as json_file:
    sotack = json.load(json_file)
    
sotack_x, sotack_y = list(),list()
for i in sotack.keys():
    sotack_x.append(sotack[i][1]['acup_coord_x'])
    sotack_y.append(sotack[i][1]['acup_coord_y'])
######################################################################    

with open('./json files/taeyeon_info_수정.json') as json_file:
    taeyeon = json.load(json_file)
    
taeyeon_x, taeyeon_y = list(),list()
for i in taeyeon.keys():
    taeyeon_x.append(taeyeon[i][1]['acup_coord_x'])
    taeyeon_y.append(taeyeon[i][1]['acup_coord_y'])
######################################################################    

with open('./json files/urjae_info_수정.json') as json_file:
    urjae = json.load(json_file)
    
urjae_x, urjae_y = list(),list()
for i in urjae.keys():
    urjae_x.append(urjae[i][1]['acup_coord_x'])
    urjae_y.append(urjae[i][1]['acup_coord_y'])

# %%
coord = pd.DataFrame([gwanchung_x,gwanchung_y,hapgok_x,hapgok_y,hugye_x,hugye_y,nogung_x,nogung_y,sangyang_x,sangyang_y,shinmoon_x,shinmoon_y,sobu_x,sobu_y,sochung_x,sochung_y,sotack_x,sotack_y,taeyeon_x,taeyeon_y,urjae_x,urjae_y],index = ['gwanchung_x','gwanchung_y','hapgok_x','hapgok_y','hugye_x','hugye_y','nogung_x','nogung_y','sangyang_x','sangyang_y','shinmoon_x','shinmoon_y','sobu_x','sobu_y','sochung_x','sochung_y','sotack_x','sotack_y','taeyeon_x','taeyeon_y','urjae_x','urjae_y']).T

# %%
coord
# Out:
#       gwanchung_x  gwanchung_y  hapgok_x  hapgok_y  hugye_x  hugye_y  \
# 0            93.0        301.0     342.0     677.0     75.0    694.0
# 1            90.0        306.0     339.0     682.0     73.0    696.0
# 2           210.0        291.0     432.0     683.0    168.0    690.0
# 3           185.0        268.0     388.0     664.0    124.0    658.0
# 4           173.0        256.0     382.0     659.0    120.0    634.0
# ...           ...          ...       ...       ...      ...      ...
# 5643          NaN          NaN       NaN       NaN      NaN      NaN
# 5644          NaN          NaN       NaN       NaN      NaN      NaN
# 5645          NaN          NaN       NaN       NaN      NaN      NaN
# 5646          NaN          NaN       NaN       NaN      NaN      NaN
# 5647          NaN          NaN       NaN       NaN      NaN      NaN
#
#       nogung_x  nogung_y  sangyang_x  sangyang_y  ...  sobu_x  sobu_y  \
# ...

# %%
coord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5648 entries, 0 to 5647
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   gwanchung_x  5507 non-null   float64
#  1   gwanchung_y  5507 non-null   float64
#  2   hapgok_x     5477 non-null   float64
#  3   hapgok_y     5477 non-null   float64
#  4   hugye_x      5527 non-null   float64
#  5   hugye_y      5527 non-null   float64
#  6   nogung_x     5364 non-null   float64
#  7   nogung_y     5364 non-null   float64
#  8   sangyang_x   5648 non-null   float64
#  9   sangyang_y   5648 non-null   float64
#  10  shinmoon_x   1020 non-null   float64
#  11  shinmoon_y   1020 non-null   float64
#  12  sobu_x       5321 non-null   float64
#  13  sobu_y       5321 non-null   float64
#  14  sochung_x    5287 non-null   float64
#  15  sochung_y    5287 non-null   float64
#  16  sotack_x     5049 non-null   float64
#  17  sotack_y     5049 non-null   float64
# ...

# %%
coord.describe()
# Out:
#        gwanchung_x  gwanchung_y     hapgok_x     hapgok_y      hugye_x  \
# count  5507.000000  5507.000000  5477.000000  5477.000000  5527.000000
# mean    369.338841   195.955874   328.120139   578.062808   334.612448
# std     109.552260    59.538213    81.462476    58.069098   168.915952
# min      60.000000    20.000000   120.000000   389.000000     3.000000
# 25%     281.000000   158.000000   264.000000   539.000000   175.000000
# 50%     371.000000   195.000000   324.000000   581.000000   371.000000
# 75%     463.000000   240.000000   389.000000   620.000000   493.000000
# max     623.000000   363.000000   515.000000   688.000000   685.000000
#
#            hugye_y     nogung_x     nogung_y   sangyang_x   sangyang_y  ...  \
# count  5527.000000  5364.000000  5364.000000  5648.000000  5648.000000  ...
# mean    526.611905   345.935309   462.649142   365.130312   204.572238  ...
# std      63.977634    82.677464    57.491498   106.508277    59.009477  ...
# ...

# %%
plt.boxplot([gwanchung_x, gwanchung_y],labels=['gwanchung_x', 'gwanchung_y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0a4c0dd88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0a4c163c8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d0a4c0d108>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0a4c168c8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0a4bfbf08>,
# ...
#  'means': []}

# %%
plt.boxplot([hapgok_x,hapgok_y],labels=['hapgok_x','hapgok_y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0a635ca48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0a6360a48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d0a635c888>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0a6363a08>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0a6368888>,
# ...
#  'means': []}

# %%
plt.boxplot([hugye_x,hugye_y],labels=['hugye_x','hugye_y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0a63e5948>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0a63e7e08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d0a63e5788>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0a63ecc88>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0a63ecdc8>,
# ...
#  'means': []}

# %%
plt.boxplot([nogung_x,nogung_y],labels=['nogung_x','nogung_y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0a646eec8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0a6472d88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d0a646e648>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0a6476d88>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0a6476f08>,
# ...
#  'means': []}

# %%
plt.boxplot([sangyang_x,sangyang_y],labels=['sangyang_x','sangyang_y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0a64ed8c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0a64f16c8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d0a64e8f48>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0a64f1f08>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0a64f8c48>,
# ...
#  'means': []}

# %%
plt.boxplot([shinmoon_x,shinmoon_y],labels=['shinmoon_x','shinmoon_y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0a656de08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0a6571c08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d0a656d588>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0a6576a88>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0a6576bc8>,
# ...
#  'means': []}

# %%
plt.boxplot([sobu_x,sobu_y],labels=['sobu_x','sobu_y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0a65efdc8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0a65f4bc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d0a65ef548>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0a65faa48>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0a65fab88>,
# ...
#  'means': []}

# %%
plt.boxplot([sochung_x,sochung_y],labels=['sochung_x','sochung_y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0a6673e08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0a6677c08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d0a6673588>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0a667ba88>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0a667bbc8>,
# ...
#  'means': []}

# %%
plt.boxplot([sotack_x,sotack_y],labels=['sotack_x','sotack_y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0a66f4f48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0a66f8e48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d0a66f4d88>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0a66fdc88>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0a6703ac8>,
# ...
#  'means': []}

# %%
plt.boxplot([taeyeon_x,taeyeon_y],labels=['taeyeon_x','taeyeon_y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0a677ba48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0a677ef08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d0a677b888>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0a6783dc8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0a6783f48>,
# ...
#  'means': []}

# %%
plt.boxplot([urjae_x,urjae_y],labels=['urjae_x','urjae_y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0a6800c08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0a6804a08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d0a6800388>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0a680a8c8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0a680aa48>,
# ...
#  'means': []}
