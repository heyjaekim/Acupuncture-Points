# %%
from os import listdir, makedirs
from os.path import isfile, isdir, join
import cv2, copy, json, os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import PIL
import zipfile

# %%
from img_aug_refined import *

# %%
# CV_DeepLearning 폴더에 Acu_Dataset 폴더 생성 
if not (os.path.isdir('../CV_DeepLearning/Acu_Dataset')):
    os.mkdir('../CV_DeepLearning/Acu_Dataset')

# %%
# Acu_Dataset 폴더에 org 파일 불러들이는 작업 필요 (구글 드라이브 API 연동 )
#################

# need to code

################

# %%
# Acu_Dataset 폴더에 저장된 압축 파일들 푸는 과정 

dset_path = '../CV_DeepLearning/Acu_Dataset'
dset_list = os.listdir(dset_path)

for d in dset_list:
    d_zip_loc = os.path.join(dset_path,d)
    if zipfile.is_zipfile(d_zip_loc):
        d_zip = zipfile.ZipFile(d_zip_loc)
        d_zip.extractall(path = dset_path)
        os.remove(d_zip_loc)
        
# Acu_Dataset 폴더에 저장된 파일 및 디렉토리 필요에 맞게  정리 
#clean_and_rename_directory(dirlist=dset_path)

# %%
# cropping 할 배경 이미지 (aug) 리스트 
dir1 = './background-images/'
imdirs = os.listdir(dir1)
imlist = [ plt.imread(dir1 + i) for i in imdirs ]

###Quick Check ###
random_indx = np.random.randint(low = 0,high = 4, size = len(imlist))
print('testing images')
plt.imshow(rand_crop_img(imlist[random_indx[0]]))
# Out:
# testing images

# %%
os.chdir('../CV_DeepLearning')
os.getcwd()
# 'C:\\Users\\NormalKim\\[0_ACU_FINAL_0830]\\CV_DeepLearning'
# Out:
# 'C:\\Users\\NormalKim\\[0_ACU_FINAL_0830]\\CV_DeepLearning'

# %%
# sctr -> sctr + filled 
augment_hands('hapgok', save_name = 'sctr_filled', img_folder = 'sctr', 
               json_name = 'hapgok_sctr',imlist = imlist, chg_flag = True)

# %%
# org -> sctr
augment_hands('hapgok', save_name = 'sctr', img_folder = 'org')
# org -> rotated
augment_hands('hapgok', save_name = 'rotated', img_folder = 'org')
# org -> filled
augment_hands('hapgok', save_name = 'filled', img_folder = 'org', imlist = imlist)

# rotated -> rotated + filled
augment_hands('hapgok', save_name = 'sctr_rotated', img_folder = 'rotated', 
               json_name = 'hapgok_rotated', imlist = imlist, chg_flag = True)

# sctr -> sctr + filled 
augment_hands('hapgok', save_name = 'sctr_filled', img_folder = 'sctr', 
               json_name = 'hapgok_sctr',imlist = imlist, chg_flag = True)

# %%
# Out:
# starting:  hapgok    sctr_filled
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6bda0c92f18d> in <module>
#       1 # sctr -> sctr + filled
# ----> 2 augment_hands('hapgok', save_name = 'sctr_filled', img_folder = 'sctr',
#       3                json_name = 'hapgok_sctr',imlist = imlist, chg_flag = True)
#
# ~\[0_ACU_FINAL_0830]\Image-Preprocess\img_aug_refined.py in augment_hands(class_label, save_name, img_folder, json_name, imlist, chg_flag)
#     551
#     552     elif 'filled' in save_name.split('_')[-1]:
# --> 553         fill_background_image2( org_path, json_data, save_name, save_path, imlist, chg_flag)
#     554
#     555     elif 'sctr' in save_name.split('_')[-1]:
#
# ~\[0_ACU_FINAL_0830]\Image-Preprocess\img_aug_refined.py in fill_background_image2(org_path, json_data, save_name, save_path, imlist, chg_flag)
#     304
#     305         # read the image file, then generate image
# --> 306         img = clear_background(cv2.imread(img_path, cv2.IMREAD_UNCHANGED))
#     307         height, width = img.shape[:2]
#     308         im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # np format
#
# NameError: name 'clear_background' is not defined
