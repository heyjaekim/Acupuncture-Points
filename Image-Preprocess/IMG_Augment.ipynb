# %%
from os import listdir, makedirs
from os.path import isfile, isdir, join
import cv2, copy, json, os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import PIL
import zipfile

# %%
from img_aug_refined import *

# %%
# CV_DeepLearning 폴더에 Acu_Dataset 폴더 생성 
if not (os.path.isdir('../CV_DeepLearning/Acu_Dataset')):
    os.mkdir('../CV_DeepLearning/Acu_Dataset')

# %%
# Acu_Dataset 폴더에 org 파일 불러들이는 작업 필요 (구글 드라이브 API 연동 )
#################

# need to code

################

# %%
# Acu_Dataset 폴더에 저장된 압축 파일들 푸는 과정 

dset_path = '../CV_DeepLearning/Acu_Dataset'
dset_list = os.listdir(dset_path)

for d in dset_list:
    d_zip_loc = os.path.join(dset_path,d)
    if zipfile.is_zipfile(d_zip_loc):
        d_zip = zipfile.ZipFile(d_zip_loc)
        d_zip.extractall(path = dset_path)
        os.remove(d_zip_loc)
        
# Acu_Dataset 폴더에 저장된 파일 및 디렉토리 필요에 맞게  정리 
#clean_and_rename_directory(dirlist=dset_path)

# %%
# cropping 할 배경 이미지 (aug) 리스트 
dir1 = './background-images/'
imdirs = os.listdir(dir1)
imlist = [ plt.imread(dir1 + i) for i in imdirs ]

###Quick Check ###
random_indx = np.random.randint(low = 0,high = 4, size = len(imlist))
print('testing images')
plt.imshow(rand_crop_img(imlist[random_indx[0]]))
# Out:
# testing images

# %%
os.chdir('../CV_DeepLearning')
os.getcwd()
# 'C:\\Users\\NormalKim\\[0_ACU_FINAL_0830]\\CV_DeepLearning'
# Out:
# 'C:\\Users\\NormalKim\\[0_ACU_FINAL_0830]\\CV_DeepLearning'

# %%
aug_cls = 'hapgok'

# sctr -> sctr + filled 
augment_hands(aug_cls, save_name = 'sctr_filled', img_folder = 'sctr', 
               json_name = f'{aug_cls}_sctr',imlist = imlist, chg_flag = True)
# Out:
# starting:  hapgok    sctr_filled
# completed 0 images to fill
# completed 10 images to fill
# completed 20 images to fill
# completed 30 images to fill
# completed 40 images to fill
# completed 50 images to fill
# completed 60 images to fill
# completed 70 images to fill
# completed 80 images to fill
# completed 90 images to fill
# completed 100 images to fill
# completed 110 images to fill
# completed 120 images to fill
# completed 130 images to fill
# completed 140 images to fill
# completed 150 images to fill
# completed 160 images to fill
# completed 170 images to fill
# completed 180 images to fill
# completed 190 images to fill
# completed 200 images to fill
# completed 210 images to fill
# completed 220 images to fill
# completed 230 images to fill
# completed 240 images to fill
# completed 250 images to fill
# completed 260 images to fill
# completed 270 images to fill
# completed 280 images to fill
# completed 290 images to fill
# completed 300 images to fill
# completed 310 images to fill
# completed 320 images to fill
# completed 330 images to fill
# completed 340 images to fill
# completed 350 images to fill
# completed 360 images to fill
# completed 370 images to fill
# completed 380 images to fill
# completed 390 images to fill
# completed 400 images to fill
# completed 410 images to fill
# completed 420 images to fill
# completed 430 images to fill
# completed 440 images to fill
# completed 450 images to fill
# completed 460 images to fill
# completed 470 images to fill
# completed 480 images to fill
# completed 490 images to fill
# completed 500 images to fill
# completed 510 images to fill
# completed 520 images to fill
# completed 530 images to fill
# completed 540 images to fill
# completed 550 images to fill
# completed 560 images to fill
# completed 570 images to fill
# completed 580 images to fill
# completed 590 images to fill
# completed 600 images to fill
# completed 610 images to fill
# completed 620 images to fill
# completed 630 images to fill
# completed 640 images to fill
# completed 650 images to fill
# completed 660 images to fill
# completed 670 images to fill
# completed 680 images to fill
# completed 690 images to fill
# completed 700 images to fill
# completed 710 images to fill
# completed 720 images to fill
# completed 730 images to fill
# completed 740 images to fill
# completed 750 images to fill
# completed 760 images to fill
# completed 770 images to fill
# completed 780 images to fill
# completed 790 images to fill
# completed 800 images to fill
# completed 810 images to fill
# completed 820 images to fill
# completed 830 images to fill
# completed 840 images to fill
# completed 850 images to fill
# completed 860 images to fill
# completed 870 images to fill
# completed 880 images to fill
# completed 890 images to fill
# completed 900 images to fill
# completed 910 images to fill
# completed 920 images to fill
# completed 930 images to fill
# completed 940 images to fill
# completed 950 images to fill
# completed 960 images to fill
# completed 970 images to fill
# completed 980 images to fill
# completed 990 images to fill
# completed 1000 images to fill
# completed 1010 images to fill
# completed 1020 images to fill
# completed 1030 images to fill
# completed 1040 images to fill
# completed 1050 images to fill
# completed 1060 images to fill
# completed 1070 images to fill
# completed 1080 images to fill
# completed 1090 images to fill
# completed 1100 images to fill
# completed 1110 images to fill
# completed 1120 images to fill
# completed 1130 images to fill
# completed 1140 images to fill
# completed 1150 images to fill
# completed 1160 images to fill
# completed 1170 images to fill
# completed 1180 images to fill
# completed 1190 images to fill
# completed 1200 images to fill
# completed 1210 images to fill
# completed 1220 images to fill
# completed 1230 images to fill
# completed 1240 images to fill
# completed 1250 images to fill
# completed 1260 images to fill
# completed 1270 images to fill
# completed 1280 images to fill
# completed 1290 images to fill
# completed 1300 images to fill
# completed 1310 images to fill
# completed 1320 images to fill
# completed 1330 images to fill
# completed 1340 images to fill
# completed 1350 images to fill
# completed 1360 images to fill
# completed 1370 images to fill
# completed 1380 images to fill
# completed 1390 images to fill
# completed 1400 images to fill
# completed 1410 images to fill
# completed 1420 images to fill
# completed 1430 images to fill
# completed 1440 images to fill
# completed 1450 images to fill
# completed 1460 images to fill
# completed 1470 images to fill
# completed 1480 images to fill
# completed 1490 images to fill
# completed 1500 images to fill
# completed 1510 images to fill
# completed 1520 images to fill
# completed 1530 images to fill
# completed 1540 images to fill
# completed 1550 images to fill
# completed 1560 images to fill
# completed 1570 images to fill
# completed 1580 images to fill
# completed 1590 images to fill
# completed 1600 images to fill
# completed 1610 images to fill
# completed 1620 images to fill
# completed 1630 images to fill
# completed 1640 images to fill
# completed 1650 images to fill
# completed 1660 images to fill
# completed 1670 images to fill
# completed 1680 images to fill
# completed 1690 images to fill
# completed 1700 images to fill
# completed 1710 images to fill
# completed 1720 images to fill
# completed 1730 images to fill
# completed 1740 images to fill
# completed 1750 images to fill
# completed 1760 images to fill
# completed 1770 images to fill
# completed 1780 images to fill
# completed 1790 images to fill
# completed 1800 images to fill
# completed 1810 images to fill
# completed 1820 images to fill
# completed 1830 images to fill
# completed 1840 images to fill
# completed 1850 images to fill
# completed 1860 images to fill
# completed 1870 images to fill
# completed 1880 images to fill
# completed 1890 images to fill
# completed 1900 images to fill
# completed 1910 images to fill
# completed 1920 images to fill
# completed 1930 images to fill
# completed 1940 images to fill
# completed 1950 images to fill
# completed 1960 images to fill
# completed 1970 images to fill
# completed 1980 images to fill
# completed 1990 images to fill
# completed 2000 images to fill
# completed 2010 images to fill
# completed 2020 images to fill
# completed 2030 images to fill
# completed 2040 images to fill
# completed 2050 images to fill
# completed 2060 images to fill
# completed 2070 images to fill
# completed 2080 images to fill
# completed 2090 images to fill
# completed 2100 images to fill
# completed 2110 images to fill
# completed 2120 images to fill
# completed 2130 images to fill
# completed 2140 images to fill
# completed 2150 images to fill
# completed 2160 images to fill
# completed 2170 images to fill
# completed 2180 images to fill
# completed 2190 images to fill
# completed 2200 images to fill
# completed 2210 images to fill
# completed 2220 images to fill
# completed 2230 images to fill
# completed 2240 images to fill
# completed 2250 images to fill
# completed 2260 images to fill
# completed 2270 images to fill
# completed 2280 images to fill
# completed 2290 images to fill
# completed 2300 images to fill
# completed 2310 images to fill
# completed 2320 images to fill
# completed 2330 images to fill
# completed 2340 images to fill
# completed 2350 images to fill
# completed 2360 images to fill
# completed 2370 images to fill
# completed 2380 images to fill
# completed 2390 images to fill
# completed 2400 images to fill
# completed 2410 images to fill
# completed 2420 images to fill
# completed 2430 images to fill
# completed 2440 images to fill
# completed 2450 images to fill
# completed 2460 images to fill
# completed 2470 images to fill
# completed 2480 images to fill
# completed 2490 images to fill
# completed 2500 images to fill
# completed 2510 images to fill
# completed 2520 images to fill
# completed 2530 images to fill
# completed 2540 images to fill
# completed 2550 images to fill
# completed 2560 images to fill
# completed 2570 images to fill
# completed 2580 images to fill
# completed 2590 images to fill
# completed 2600 images to fill
# completed 2610 images to fill
# completed 2620 images to fill
# completed 2630 images to fill
# completed 2640 images to fill
# completed 2650 images to fill
# completed 2660 images to fill
# completed 2670 images to fill
# completed 2680 images to fill
# completed 2690 images to fill
# completed 2700 images to fill
# completed 2710 images to fill
# completed 2720 images to fill
# completed 2730 images to fill
# completed 2740 images to fill
# completed 2750 images to fill
# completed 2760 images to fill
# completed 2770 images to fill
# completed 2780 images to fill
# completed 2790 images to fill
# completed 2800 images to fill
# completed 2810 images to fill
# completed 2820 images to fill
# completed 2830 images to fill
# completed 2840 images to fill
# completed 2850 images to fill
# completed 2860 images to fill
# completed 2870 images to fill
# completed 2880 images to fill
# completed 2890 images to fill
# completed 2900 images to fill
# completed 2910 images to fill
# completed 2920 images to fill
# completed 2930 images to fill
# completed 2940 images to fill
# completed 2950 images to fill
# completed 2960 images to fill
# completed 2970 images to fill
# completed 2980 images to fill
# completed 2990 images to fill
# completed 3000 images to fill
# completed 3010 images to fill
# completed 3020 images to fill
# completed 3030 images to fill
# completed 3040 images to fill
# completed 3050 images to fill
# completed 3060 images to fill
# completed 3070 images to fill
# completed 3080 images to fill
# completed 3090 images to fill
# completed 3100 images to fill
# completed 3110 images to fill
# completed 3120 images to fill
# completed 3130 images to fill
# completed 3140 images to fill
# completed 3150 images to fill
# completed 3160 images to fill
# completed 3170 images to fill
# completed 3180 images to fill
# completed 3190 images to fill
# completed 3200 images to fill
# completed 3210 images to fill
# completed 3220 images to fill
# completed 3230 images to fill
# completed 3240 images to fill
# completed 3250 images to fill
# completed 3260 images to fill
# completed 3270 images to fill
# completed 3280 images to fill
# completed 3290 images to fill
# completed 3300 images to fill
# completed 3310 images to fill
# completed 3320 images to fill
# completed 3330 images to fill
# completed 3340 images to fill
# completed 3350 images to fill
# completed 3360 images to fill
# completed 3370 images to fill
# completed 3380 images to fill
# completed 3390 images to fill
# completed 3400 images to fill
# completed 3410 images to fill
# completed 3420 images to fill
# completed 3430 images to fill
# completed 3440 images to fill
# completed 3450 images to fill
# completed 3460 images to fill
# completed 3470 images to fill
# completed 3480 images to fill
# completed 3490 images to fill
# completed 3500 images to fill
# completed 3510 images to fill
# completed 3520 images to fill
# completed 3530 images to fill
# completed 3540 images to fill
# completed 3550 images to fill
# completed 3560 images to fill
# completed 3570 images to fill
# completed 3580 images to fill
# completed 3590 images to fill
# completed 3600 images to fill
# completed 3610 images to fill
# completed 3620 images to fill
# completed 3630 images to fill
# completed 3640 images to fill
# completed 3650 images to fill
# completed 3660 images to fill
# completed 3670 images to fill
# completed 3680 images to fill
# completed 3690 images to fill
# completed 3700 images to fill
# completed 3710 images to fill
# completed 3720 images to fill
# completed 3730 images to fill
# completed 3740 images to fill
# completed 3750 images to fill
# completed 3760 images to fill
# completed 3770 images to fill
# completed 3780 images to fill
# completed 3790 images to fill
# completed 3800 images to fill
# completed 3810 images to fill
# completed 3820 images to fill
# completed 3830 images to fill
# completed 3840 images to fill
# completed 3850 images to fill
# completed 3860 images to fill
# completed 3870 images to fill
# completed 3880 images to fill
# completed 3890 images to fill
# completed 3900 images to fill
# completed 3910 images to fill
# completed 3920 images to fill
# completed 3930 images to fill
# completed 3940 images to fill
# completed 3950 images to fill
# completed 3960 images to fill
# completed 3970 images to fill
# completed 3980 images to fill
# completed 3990 images to fill
# completed 4000 images to fill
# completed 4010 images to fill
# completed 4020 images to fill
# completed 4030 images to fill
# completed 4040 images to fill
# completed 4050 images to fill
# completed 4060 images to fill
# completed 4070 images to fill
# completed 4080 images to fill
# completed 4090 images to fill
# completed 4100 images to fill
# completed 4110 images to fill
# completed 4120 images to fill
# completed 4130 images to fill
# completed 4140 images to fill
# completed 4150 images to fill
# completed 4160 images to fill
# completed 4170 images to fill
# completed 4180 images to fill
# completed 4190 images to fill
# completed 4200 images to fill
# completed 4210 images to fill
# completed 4220 images to fill
# completed 4230 images to fill
# completed 4240 images to fill
# completed 4250 images to fill
# completed 4260 images to fill
# completed 4270 images to fill
# completed 4280 images to fill
# completed 4290 images to fill
# completed 4300 images to fill
# completed 4310 images to fill
# completed 4320 images to fill
# completed 4330 images to fill
# completed 4340 images to fill
# completed 4350 images to fill
# completed 4360 images to fill
# completed 4370 images to fill
# completed 4380 images to fill
# completed 4390 images to fill
# completed 4400 images to fill
# completed 4410 images to fill
# completed 4420 images to fill
# completed 4430 images to fill
# completed 4440 images to fill
# completed 4450 images to fill
# completed 4460 images to fill
# completed 4470 images to fill
# completed 4480 images to fill
# completed 4490 images to fill
# completed 4500 images to fill
# completed 4510 images to fill
# completed 4520 images to fill
# completed 4530 images to fill
# completed 4540 images to fill
# completed 4550 images to fill
# completed 4560 images to fill
# completed 4570 images to fill
# completed 4580 images to fill
# completed 4590 images to fill
# completed 4600 images to fill
# completed 4610 images to fill
# completed 4620 images to fill
# completed 4630 images to fill
# completed 4640 images to fill
# completed 4650 images to fill
# completed 4660 images to fill
# completed 4670 images to fill
# completed 4680 images to fill
# completed 4690 images to fill
# completed 4700 images to fill
# completed 4710 images to fill
# completed 4720 images to fill
# completed 4730 images to fill
# completed 4740 images to fill
# completed 4750 images to fill
# completed 4760 images to fill
# completed 4770 images to fill
# completed 4780 images to fill
# completed 4790 images to fill
# completed 4800 images to fill
# completed 4810 images to fill
# completed 4820 images to fill
# completed 4830 images to fill
# completed 4840 images to fill
# completed 4850 images to fill
# completed 4860 images to fill
# completed 4870 images to fill
# completed 4880 images to fill
# completed 4890 images to fill
# completed 4900 images to fill
# completed 4910 images to fill
# completed 4920 images to fill
# completed 4930 images to fill
# completed 4940 images to fill
# completed 4950 images to fill
# completed 4960 images to fill
# completed 4970 images to fill
# completed 4980 images to fill
# completed 4990 images to fill
# completed 5000 images to fill
# completed 5010 images to fill
# completed 5020 images to fill
# completed 5030 images to fill
# completed 5040 images to fill
# completed 5050 images to fill
# completed 5060 images to fill
# completed 5070 images to fill
# completed 5080 images to fill
# completed 5090 images to fill
# completed 5100 images to fill
# completed 5110 images to fill
# completed 5120 images to fill
# completed 5130 images to fill
# completed 5140 images to fill
# completed 5150 images to fill
# completed 5160 images to fill
# completed 5170 images to fill
# completed 5180 images to fill
# completed 5190 images to fill
# completed 5200 images to fill
# completed 5210 images to fill
# completed 5220 images to fill
# completed 5230 images to fill
# completed 5240 images to fill
# completed 5250 images to fill
# completed 5260 images to fill
# completed 5270 images to fill
# completed 5280 images to fill
# completed 5290 images to fill
# completed 5300 images to fill
# completed 5310 images to fill
# completed 5320 images to fill
# completed 5330 images to fill
# completed 5340 images to fill
# completed 5350 images to fill
# completed 5360 images to fill
# completed 5370 images to fill
# completed 5380 images to fill
# completed 5390 images to fill
# completed 5400 images to fill
# completed 5410 images to fill
# completed 5420 images to fill
# completed 5430 images to fill
# completed 5440 images to fill
# completed 5450 images to fill
# completed 5460 images to fill
# completed 5470 images to fill

# %%
# 기존 데이터셋 -> 학습 데이터 6배 증가  
# filled data: 보통 5000장 ~ 40분

# org -> sctr
augment_hands(aug_cls, save_name = 'sctr', img_folder = 'org') 

# org -> rotated
augment_hands(aug_cls, save_name = 'rotated', img_folder = 'org')

# org -> filled
augment_hands(aug_cls, save_name = 'filled', img_folder = 'org', imlist = imlist) #

# rotated -> rotated + filled
augment_hands(aug_cls, save_name = 'sctr_rotated', img_folder = 'rotated', 
               json_name = f'{aug_cls}_rotated', imlist = imlist, chg_flag = True)

# sctr -> sctr + filled 
augment_hands(aug_cls, save_name = 'sctr_filled', img_folder = 'sctr', 
               json_name = f'{aug_cls}_sctr',imlist = imlist, chg_flag = True)
